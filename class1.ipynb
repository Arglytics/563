# %% [markdown]
# <a href="https://colab.research.google.com/github/Arglytics/563/blob/main/class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#figure out how many ways to fit 20 particles in a volume of 4-billion by 4- billion
print("hello class")
a=20
b=[1,23,"string"]
# Out:
# hello class

# %%
print(b)
# Out:
# [1, 23, 'string']

# %%
#Am ready to work on the problem now

places_can_sit =(4*10**9)**2

# %%
print(places_can_sit**20)
# Out:
# 

# %%
#How many years will it take to evaluate these configurations(configs) with 2.67 billion calculations per second?

# %%
n=places_can_sit**20
n//(267*10**7)//3600//24//365//(10**367) #seconds
#divide by hours then years then days
# Out:
# 1
